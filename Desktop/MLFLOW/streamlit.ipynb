# %%
# ipynb is a jupyter notebook

# %%
import pandas as pd
import numpy as np
import streamlit as st
import matplotlib.pyplot as plt

# %%
! pip install streamlit

# %%
# ui for mlflow user can give input and see the output
# create a calculator which do addition, subtraction, multiplication and division
st.write("Welcome to the calculator app"
        "Please enter two numbers and select the operation you want to perform")
#input fields for the two numbers
num1 = st.number_input("Enter the first number")
num2 = st.number_input("Enter the second number")
#prepare the the caclulation
# Out:
# 2026-03-25 12:02:04.060 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-25 12:02:04.768
# ...
#   command:
#
#     streamlit run c:\Users\lenevo\anaconda3\envs\ml_env\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-03-25 12:02:04.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-25 12:02:04.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-25 12:02:04.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-25 12:02:04.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-25 12:02:04.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
